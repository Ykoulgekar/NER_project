# %%
## In this notebook i try to build POS tagging and NER (Name entity recognision)

# %%
import spacy

# %%
nlp_tagg = spacy.load("en_core_web_sm")

# %%
text = """Background and context
In 1636, the Adil Shahi sultanate of Bijapur invaded the kingdoms to its south.[6] The sultanate had recently become a tributary state of the Mughal empire.[6][32] It was being helped by Shahaji, who at the time was a chieftain in the Maratha uplands of western India. Shahaji was looking for opportunities of rewards of jagir land in the conquered territories, the taxes on which he could collect as an annuity.[6]

Shahaji was a rebel from brief Mughal service. Shahaji's campaigns against the Mughals, supported by the Bijapur government, were generally unsuccessful. He was constantly pursued by the Mughal army, and Shivaji and his mother Jijabai had to move from fort to fort.[33]


Young Shivaji (right) meets his father Shahaji. (left)
In 1636, Shahaji joined in the service of Bijapur and obtained Poona as a grant. Shahaji, being deployed in Bangalore by the Bijapuri ruler Adilshah, appointed Dadoji Kondadeo as Poona's administrator. Shivaji and Jijabai settled in Poona.[34] Kondadeo died in 1647 and Shivaji took over its administration. One of his first acts directly challenged the Bijapuri government."""

# %%
doc = nlp_tagg(text)

# %%
for word in doc:
  print(word , "==>",word.pos_,"==>",spacy.explain(word.pos_))
# Out:
# Background ==> NOUN ==> noun
# and ==> CCONJ ==> coordinating conjunction
# context ==> NOUN ==> noun
#
#  ==> SPACE ==> space
# In ==> ADP ==> adposition
# 1636 ==> NUM ==> numeral
# , ==> PUNCT ==> punctuation
# the ==> DET ==> determiner
# Adil ==> PROPN ==> proper noun
# Shahi ==> PROPN ==> proper noun
# sultanate ==> NOUN ==> noun
# of ==> ADP ==> adposition
# Bijapur ==> PROPN ==> proper noun
# invaded ==> VERB ==> verb
# the ==> DET ==> determiner
# kingdoms ==> NOUN ==> noun
# to ==> ADP ==> adposition
# its ==> PRON ==> pronoun
# south.[6 ==> NUM ==> numeral
# ] ==> PUNCT ==> punctuation
# The ==> DET ==> determiner
# sultanate ==> NOUN ==> noun
# had ==> AUX ==> auxiliary
# recently ==> ADV ==> adverb
# become ==> VERB ==> verb
# a ==> DET ==> determiner
# tributary ==> NOUN ==> noun
# state ==> NOUN ==> noun
# of ==> ADP ==> adposition
# the ==> DET ==> determiner
# Mughal ==> PROPN ==> proper noun
# empire.[6][32 ==> PROPN ==> proper noun
# ] ==> PUNCT ==> punctuation
# It ==> PRON ==> pronoun
# was ==> AUX ==> auxiliary
# being ==> AUX ==> auxiliary
# helped ==> VERB ==> verb
# by ==> ADP ==> adposition
# Shahaji ==> PROPN ==> proper noun
# , ==> PUNCT ==> punctuation
# who ==> PRON ==> pronoun
# at ==> ADP ==> adposition
# the ==> DET ==> determiner
# time ==> NOUN ==> noun
# was ==> AUX ==> auxiliary
# a ==> DET ==> determiner
# chieftain ==> NOUN ==> noun
# in ==> ADP ==> adposition
# the ==> DET ==> determiner
# Maratha ==> PROPN ==> proper noun
# uplands ==> NOUN ==> noun
# of ==> ADP ==> adposition
# western ==> ADJ ==> adjective
# India ==> PROPN ==> proper noun
# . ==> PUNCT ==> punctuation
# Shahaji ==> PROPN ==> proper noun
# was ==> AUX ==> auxiliary
# looking ==> VERB ==> verb
# for ==> ADP ==> adposition
# opportunities ==> NOUN ==> noun
# of ==> ADP ==> adposition
# rewards ==> NOUN ==> noun
# of ==> ADP ==> adposition
# jagir ==> PROPN ==> proper noun
# land ==> NOUN ==> noun
# in ==> ADP ==> adposition
# the ==> DET ==> determiner
# conquered ==> ADJ ==> adjective
# territories ==> NOUN ==> noun
# , ==> PUNCT ==> punctuation
# the ==> DET ==> determiner
# taxes ==> NOUN ==> noun
# on ==> ADP ==> adposition
# which ==> PRON ==> pronoun
# he ==> PRON ==> pronoun
# could ==> AUX ==> auxiliary
# collect ==> VERB ==> verb
# as ==> ADP ==> adposition
# an ==> DET ==> determiner
# annuity.[6 ==> X ==> other
# ] ==> X ==> other
#
#
#  ==> SPACE ==> space
# Shahaji ==> PROPN ==> proper noun
# was ==> AUX ==> auxiliary
# a ==> DET ==> determiner
# rebel ==> NOUN ==> noun
# from ==> ADP ==> adposition
# brief ==> ADJ ==> adjective
# Mughal ==> PROPN ==> proper noun
# service ==> NOUN ==> noun
# . ==> PUNCT ==> punctuation
# Shahaji ==> PROPN ==> proper noun
# 's ==> PART ==> particle
# campaigns ==> NOUN ==> noun
# against ==> ADP ==> adposition
# the ==> DET ==> determiner
# Mughals ==> NOUN ==> noun
# , ==> PUNCT ==> punctuation
# supported ==> VERB ==> verb
# by ==> ADP ==> adposition
# the ==> DET ==> determiner
# Bijapur ==> PROPN ==> proper noun
# government ==> NOUN ==> noun
# , ==> PUNCT ==> punctuation
# were ==> AUX ==> auxiliary
# generally ==> ADV ==> adverb
# unsuccessful ==> ADJ ==> adjective
# . ==> PUNCT ==> punctuation
# He ==> PRON ==> pronoun
# was ==> AUX ==> auxiliary
# constantly ==> ADV ==> adverb
# pursued ==> VERB ==> verb
# by ==> ADP ==> adposition
# the ==> DET ==> determiner
# Mughal ==> PROPN ==> proper noun
# army ==> NOUN ==> noun
# , ==> PUNCT ==> punctuation
# and ==> CCONJ ==> coordinating conjunction
# Shivaji ==> PROPN ==> proper noun
# and ==> CCONJ ==> coordinating conjunction
# his ==> PRON ==> pronoun
# mother ==> NOUN ==> noun
# Jijabai ==> PROPN ==> proper noun
# had ==> VERB ==> verb
# to ==> PART ==> particle
# move ==> VERB ==> verb
# from ==> ADP ==> adposition
# fort ==> NOUN ==> noun
# to ==> ADP ==> adposition
# fort.[33 ==> PROPN ==> proper noun
# ] ==> X ==> other
#
#
#
#  ==> SPACE ==> space
# Young ==> PROPN ==> proper noun
# Shivaji ==> PROPN ==> proper noun
# ( ==> PUNCT ==> punctuation
# right ==> NOUN ==> noun
# ) ==> PUNCT ==> punctuation
# meets ==> VERB ==> verb
# his ==> PRON ==> pronoun
# father ==> NOUN ==> noun
# Shahaji ==> PROPN ==> proper noun
# . ==> PUNCT ==> punctuation
# ( ==> PUNCT ==> punctuation
# left ==> VERB ==> verb
# ) ==> PUNCT ==> punctuation
#
#  ==> SPACE ==> space
# In ==> ADP ==> adposition
# 1636 ==> NUM ==> numeral
# , ==> PUNCT ==> punctuation
# Shahaji ==> PROPN ==> proper noun
# joined ==> VERB ==> verb
# in ==> ADP ==> adposition
# the ==> DET ==> determiner
# service ==> NOUN ==> noun
# of ==> ADP ==> adposition
# Bijapur ==> PROPN ==> proper noun
# and ==> CCONJ ==> coordinating conjunction
# obtained ==> VERB ==> verb
# Poona ==> PROPN ==> proper noun
# as ==> ADP ==> adposition
# a ==> DET ==> determiner
# grant ==> NOUN ==> noun
# . ==> PUNCT ==> punctuation
# Shahaji ==> PROPN ==> proper noun
# , ==> PUNCT ==> punctuation
# being ==> AUX ==> auxiliary
# deployed ==> VERB ==> verb
# in ==> ADP ==> adposition
# Bangalore ==> PROPN ==> proper noun
# by ==> ADP ==> adposition
# the ==> DET ==> determiner
# Bijapuri ==> PROPN ==> proper noun
# ruler ==> NOUN ==> noun
# Adilshah ==> PROPN ==> proper noun
# , ==> PUNCT ==> punctuation
# appointed ==> VERB ==> verb
# Dadoji ==> PROPN ==> proper noun
# Kondadeo ==> PROPN ==> proper noun
# as ==> ADP ==> adposition
# Poona ==> PROPN ==> proper noun
# 's ==> PART ==> particle
# administrator ==> NOUN ==> noun
# . ==> PUNCT ==> punctuation
# Shivaji ==> PROPN ==> proper noun
# and ==> CCONJ ==> coordinating conjunction
# Jijabai ==> PROPN ==> proper noun
# settled ==> VERB ==> verb
# in ==> ADP ==> adposition
# Poona.[34 ==> PROPN ==> proper noun
# ] ==> PUNCT ==> punctuation
# Kondadeo ==> PROPN ==> proper noun
# died ==> VERB ==> verb
# in ==> ADP ==> adposition
# 1647 ==> NUM ==> numeral
# and ==> CCONJ ==> coordinating conjunction
# Shivaji ==> PROPN ==> proper noun
# took ==> VERB ==> verb
# over ==> ADP ==> adposition
# its ==> PRON ==> pronoun
# administration ==> NOUN ==> noun
# . ==> PUNCT ==> punctuation
# One ==> NUM ==> numeral
# of ==> ADP ==> adposition
# his ==> PRON ==> pronoun
# first ==> ADJ ==> adjective
# acts ==> NOUN ==> noun
# directly ==> ADV ==> adverb
# challenged ==> VERB ==> verb
# the ==> DET ==> determiner
# Bijapuri ==> PROPN ==> proper noun
# government ==> NOUN ==> noun
# . ==> PUNCT ==> punctuation

# %%
for tagg in nlp_tagg.get_pipe("tagger").labels:
  print(tagg ,"==>",spacy.explain(tagg))
# Out:
# $ ==> symbol, currency
# '' ==> closing quotation mark
# , ==> punctuation mark, comma
# -LRB- ==> left round bracket
# -RRB- ==> right round bracket
# . ==> punctuation mark, sentence closer
# : ==> punctuation mark, colon or ellipsis
# ADD ==> email
# AFX ==> affix
# CC ==> conjunction, coordinating
# CD ==> cardinal number
# DT ==> determiner
# EX ==> existential there
# FW ==> foreign word
# HYPH ==> punctuation mark, hyphen
# IN ==> conjunction, subordinating or preposition
# JJ ==> adjective (English), other noun-modifier (Chinese)
# JJR ==> adjective, comparative
# JJS ==> adjective, superlative
# LS ==> list item marker
# MD ==> verb, modal auxiliary
# NFP ==> superfluous punctuation
# NN ==> noun, singular or mass
# NNP ==> noun, proper singular
# NNPS ==> noun, proper plural
# NNS ==> noun, plural
# PDT ==> predeterminer
# POS ==> possessive ending
# PRP ==> pronoun, personal
# PRP$ ==> pronoun, possessive
# RB ==> adverb
# RBR ==> adverb, comparative
# RBS ==> adverb, superlative
# RP ==> adverb, particle
# SYM ==> symbol
# TO ==> infinitival "to"
# UH ==> interjection
# VB ==> verb, base form
# VBD ==> verb, past tense
# VBG ==> verb, gerund or present participle
# VBN ==> verb, past participle
# VBP ==> verb, non-3rd person singular present
# VBZ ==> verb, 3rd person singular present
# WDT ==> wh-determiner
# WP ==> wh-pronoun, personal
# WP$ ==> wh-pronoun, possessive
# WRB ==> wh-adverb
# XX ==> unknown
# _SP ==> whitespace
# `` ==> opening quotation mark

# %% [markdown]
# ## NER

# %%
ner = spacy.load("en_core_web_sm")

# %%
doc_ner = ner(text)

# %%
doc_ner.ents[5].label_
# Out:
# 'LOC'

# %%
for word in doc_ner.ents:
  print(word.text , "==>",word.label_)
# Out:
# 1636 ==> DATE
# Adil Shahi ==> ORG
# Bijapur ==> GPE
# the Mughal empire.[6][32] ==> ORG
# Shahaji ==> ORG
# Maratha ==> LOC
# India ==> GPE
# Mughal ==> PERSON
# Shahaji ==> ORG
# Mughals ==> ORG
# Mughal ==> PERSON
# Shivaji ==> PERSON
# Jijabai ==> GPE
# fort ==> GPE
# Young Shivaji ==> PERSON
# Shahaji ==> PERSON
# 1636 ==> DATE
# Shahaji ==> ORG
# Bijapur ==> GPE
# Poona ==> PERSON
# Bijapuri ==> LOC
# Adilshah ==> PERSON
# Dadoji Kondadeo ==> PERSON
# Poona ==> PERSON
# Shivaji ==> PERSON
# Jijabai ==> GPE
# 1647 ==> DATE
# Shivaji ==> PERSON
# One ==> CARDINAL
# first ==> ORDINAL
# Bijapuri ==> LOC

# %%
from spacy import displacy

# %%
displacy.render(doc_ner.ents,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1636
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adil Shahi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bijapur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Mughal empire.[6][32]
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shahaji
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maratha
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mughal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shahaji
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mughals
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mughal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shivaji
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jijabai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fort
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Young Shivaji
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shahaji
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1636
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shahaji
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bijapur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Poona
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bijapuri
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc;

# %% [markdown]
# # Added custom word (Dictionary based)

# %%
from spacy.tokens import Span

# %%
doc_ner[8:9]
# Out:
# Adil

# %%
Span_= Span(doc_ner, 8, 9, label = "Name")

# %%
doc_ner.set_ents([Span_],default='unmodified')

# %%
for ents in doc_ner.ents:
  print(ents.text ,"==>" ,ents.label_)
# Out:
# 1636 ==> DATE
# Adil ==> Name
# Shahi ==> ORG
# Bijapur ==> GPE
# the Mughal empire.[6][32] ==> ORG
# Shahaji ==> ORG
# Maratha ==> LOC
# India ==> GPE
# Mughal ==> PERSON
# Shahaji ==> ORG
# Mughals ==> ORG
# Mughal ==> PERSON
# Shivaji ==> PERSON
# Jijabai ==> GPE
# fort ==> GPE
# Young Shivaji ==> PERSON
# Shahaji ==> PERSON
# 1636 ==> DATE
# Shahaji ==> ORG
# Bijapur ==> GPE
# Poona ==> PERSON
# Bijapuri ==> LOC
# Adilshah ==> PERSON
# Dadoji Kondadeo ==> PERSON
# Poona ==> PERSON
# Shivaji ==> PERSON
# Jijabai ==> GPE
# 1647 ==> DATE
# Shivaji ==> PERSON
# One ==> CARDINAL
# first ==> ORDINAL
# Bijapuri ==> LOC

# %% [markdown]
# # Custom word added in NER (Rule Based)

# %%
from spacy.pipeline import EntityRuler

# %%
pattern = [{"label":"PHONE","pattern":"1636"}]

# %%
ruler = ner.add_pipe("entity_ruler",before="ner")

# %%
ruler.add_patterns(pattern)

# %%
for ents in doc_ner.ents:
  print(ents.text ,"==>" ,ents.label_)
# Out:
# 1636 ==> DATE
# Adil ==> Name
# Shahi ==> ORG
# Bijapur ==> GPE
# the Mughal empire.[6][32] ==> ORG
# Shahaji ==> ORG
# Maratha ==> LOC
# India ==> GPE
# Mughal ==> PERSON
# Shahaji ==> ORG
# Mughals ==> ORG
# Mughal ==> PERSON
# Shivaji ==> PERSON
# Jijabai ==> GPE
# fort ==> GPE
# Young Shivaji ==> PERSON
# Shahaji ==> PERSON
# 1636 ==> DATE
# Shahaji ==> ORG
# Bijapur ==> GPE
# Poona ==> PERSON
# Bijapuri ==> LOC
# Adilshah ==> PERSON
# Dadoji Kondadeo ==> PERSON
# Poona ==> PERSON
# Shivaji ==> PERSON
# Jijabai ==> GPE
# 1647 ==> DATE
# Shivaji ==> PERSON
# One ==> CARDINAL
# first ==> ORDINAL
# Bijapuri ==> LOC

# %% [markdown]
# #Fine tunning

# %%
## Labeling

##prodi.g

# %%
import spacy
from spacy.tokens import DocBin

# %%
nlp = spacy.blank("en")
db = DocBin()
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)

# %%
import json
file = open("/content/annotations.json")
train_data = json.load(file)

# %%
train_data
# Out:
# {'classes': ['MAHARAJ', 'VARSH', 'DUSHMAN', 'RAJMATA'],
#  'annotations': [['Shivaji was the founder of the Maratha Empire. He was born in the Shivneri Fort in Maharashtra probably on 19 February 1630. He is named after a local goddess, Shivai Devi.\r\n\r\nShivaji is one of the revered historical figures of Maharashtra. He created an independent and sovereign state in the Maharashtra region. His mother, Raajmaata Jijabai was the daughter of Shri.Lakhuji Jadhavrao of Sindkhed. His father Shri.Shahajiraje Bhosale was a Maratha general in the Deccan.\r\n\r\nMost of the territory in Maharashtra was then under the possession of the Nizamshah of Ahmednagar and the Adilshah of Bijapur who were known as the Deccan sultanates. The Mughals launched a campaign to conquer the Nizamshahi Kingdom. The Adilshah of Bijapur allied with the Mughals in this campaign. Shri. Shahajiraje Bhosale tried to rebel, but he could not withstand the combined might of the Mughals and the Adilshahi. The Nizamshahi kingdom came to an end in 1636. Thereafter Shri.Shahajiraje became a Sardar of the Adilshah of Bijapur and was posted in Karnataka. The region comprising Pune, Supe, Indapur, and Chakan Parganas located between the Bhima and Nira rivers which were vested in Shri. Shahdara as a jagir was continued by the Adilshah. Shri. Shahdara was also given a jagir of Bangalore. Rajmata Jijabai and Chh. Shivaji , stayed for a few years with Shahaji Raje at Bangalore until Shivaji I was twelve years old. Shri. Shahaji entrusted the administration of the Lakshmi jagir to Shivaji and Mata Jijabai. \r\nShivaji grew up amidst the hills and valleys of the Pune region under the guidance of his mother Raajmata Jijabai. His mother taught him the stories of the Hindu epics and scriptures such as Mahabharata and also stories of old mighty Hindu kingdoms such as the Vijayanagara. He was also trained in guerrilla warfare. He defeated the Mughal forces of Rai Bagan.\r\nFoundation of the Maratha kingdom\r\n\r\nSeveral small spurs run eastward from the sahyadri in the Pune region. The extremely rugged valleys enclosed by these are usually known as the Mavals or Khores each named after the stream running through it, or after the principal village. Collectively they are known as the Mavals. The inhabitants of this region who are called the Mavalas were extremely hardy people. Shivaji started the work of founding the Swaraj - self-rule - in this region. He used the geographical features of the Maval region. He created a feeling of trust and affection in minds of the people. Many associates, companions, and Mavalas joined him in his work of founding Swaraj. The objective of Shivaji in founding the Swaraj is clearly expressed in his official seal or Mudra which is in Sanskrit. Through this Mudra, Shivaji Maharaj assured his people that ‘ever-increasing like the crescent moon, the kingdom of Shivaji, son of Shahaji, will always seek the welfare of the people.\r\nThe Capture of Javali.\r\n\r\nThe region of Javali in the Satara district was important. Many routes to the Konkan were through Javali. For the expansion of the Swaraj in the Konkan, it was essential to control that region. The region of Javali was ruled by Chandrarao More, a powerful Sardar in the Adilshahi. Shivaji attacked Javali and captured it in A.D. 1656. Then he also captured Rairi. This strong fort, later under the name of Raigad, was to become his capital. He built the Pratapgad fort in the Javali valley to protect the newly conquered territory and to control the Paar pass. The victory at Javali led to the expansion of the Swaraj in Konkan. Shivaji then crossed the Ghats and descended into Konkan. He captured Kalyan and Bhivandi on the Konkan coast which were under the control of Adilshahi. Shivaji also captured forts like Mahuli, Lohagad, Tunga, Tikona, Visapur, Songad, Karnala, Tala and Ghosala, in the Konkan. Shivaji was able to command the coast line because of his acquisition of this territory in the Konkan. He came in contact with the Portuguese, the British and the S ...
#    {'entities': [[0, 7, 'MAHARAJ'],
#      [176, 183, 'MAHARAJ'],
#      [326, 343, 'RAJMATA'],
#      [411, 435, 'MAHARAJ'],
#      [550, 559, 'DUSHMAN'],
#      [582, 590, 'DUSHMAN'],
#      [647, 654, 'DUSHMAN'],
#      [690, 700, 'DUSHMAN'],
#      [714, 722, 'DUSHMAN'],
#      [750, 757, 'DUSHMAN'],
#      [776, 793, 'MAHARAJ'],
#      [871, 878, 'DUSHMAN'],
#      [887, 897, 'DUSHMAN'],
#      [902, 920, 'DUSHMAN'],
#      [939, 944, 'VARSH'],
#      [956, 972, 'MAHARAJ'],
#      [996, 1004, 'DUSHMAN'],
#      [1218, 1227, 'DUSHMAN'],
#      [1280, 1295, 'RAJMATA'],
#      [1300, 1312, 'MAHARAJ'],
#      [1343, 1355, 'MAHARAJ'],
#      [1375, 1382, 'MAHARAJ'],
#      [1407, 1420, 'MAHARAJ'],
#      [1474, 1481, 'MAHARAJ'],
#      [1486, 1499, 'RAJMATA'],
#      [1502, 1509, 'MAHARAJ'],
#      [1599, 1616, 'RAJMATA'],
#      [1835, 1841, 'DUSHMAN'],
#      [1852, 1862, 'DUSHMAN'],
#      [2271, 2278, 'MAHARAJ'],
#      [2573, 2580, 'MAHARAJ'],
#      [2697, 2712, 'MAHARAJ'],
#      [2793, 2800, 'MAHARAJ'],
#      [2809, 2816, 'MAHARAJ'],
#      [3159, 3169, 'DUSHMAN'],
#      [3213, 3223, 'VARSH'],
#      [3518, 3525, 'MAHARAJ'],
#      [3660, 3670, 'DUSHMAN'],
#      [3671, 3678, 'MAHARAJ'],
#      [3795, 3802, 'MAHARAJ'],
#      [3942, 3949, 'DUSHMAN'],
#      [3958, 3963, 'DUSHMAN'],
#      [3997, 4002, 'DUSHMAN'],
#      [4168, 4175, 'MAHARAJ']]}]]}

# %%
for text ,annotation in train_data["annotations"]:
  doc = nlp.make_doc(text)
  entity = []
  for start , end , label in annotation["entities"]:
    span = doc.char_span(start , end ,label,alignment_mode='contract')
    if span is None:
      print("none")
    else:
      entity.append(span)
    doc.ents = entity
    db.add(doc)

  db.to_disk("training_data.spacy")

# %%
# !python -m spacy init config config.cfg --lang en --pipeline ner --optimize efficiency
# Out:
# ⚠ To generate a more effective transformer-based config (GPU-only),
# install the spacy-transformers package and re-run this command. The config
# generated now does not use transformers.
# ℹ Generated config template specific for your use case
# - Language: en
# - Pipeline: ner
# - Optimize for: efficiency
# - Hardware: CPU
# - Transformer: None
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy train config.cfg --output ./ --paths.train ./training_data.spacy --paths.dev ./training_data.spacy
# Out:
# ℹ Saving to output directory: .
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00    392.11    4.49    4.65    4.34    0.04
#   4     200        322.29  11440.21   70.10   76.56   64.65    0.70
#   9     400        289.47   4005.92   75.53   65.18   89.80    0.76
#  13     600        270.42   3802.82   67.27   84.09   56.06    0.67
#  18     800        242.65   3666.12   76.21   65.76   90.61    0.76
#  22    1000        326.75   3822.18   71.38   80.30   64.24    0.71
#  27    1200        223.87   3626.16   75.82   75.00   76.67    0.76
#  31    1400        233.03   3544.33   73.58   78.18   69.49    0.74
#  36    1600        231.31   3472.21   76.56   72.73   80.81    0.77
#  40    1800        937.24   3687.07   76.45   66.89   89.19    0.76
#  45    2000        364.35   3595.14   76.27   72.45   80.51    0.76
#  50    2200        405.89   3546.13   76.25   73.86   78.79    0.76
#  54    2400        378.04   3543.92   68.83   82.81   58.89    0.69
#  59    2600        435.71   3568.58   74.26   75.10   73.43    0.74
#  63    2800        418.81   3525.75   76.22   69.87   83.84    0.76
#  68    3000        417.64   3674.09   76.66   71.50   82.63    0.77
#  72    3200        337.03   3472.19   76.25   73.86   78.79    0.76
#  77    3400        370.23   3410.06   69.97   81.28   61.41    0.70
#  81    3600        390.66   3484.86   73.80   78.41   69.70    0.74
#  86    3800        410.73   3495.80   76.25   73.86   78.79    0.76
#  90    4000        415.78   3408.08   74.61   77.27   72.12    0.75
#  95    4200        475.70   3529.47   76.86   70.45   84.55    0.77
# 100    4400        566.95   3579.37   76.27   72.45   80.51    0.76
# 104    4600        515.30   3496.46   74.50   77.16   72.02    0.75
# 109    4800        576.01   3470.32   76.38   65.91   90.81    0.76
# 113    5000        600.11   3467.33   76.86   70.45   84.55    0.77
# 118    5200        688.73   3489.37   70.31   81.68   61.72    0.70
# 122    5400        622.60   3399.39   76.87   69.32   86.26    0.77
# 127    5600        645.52   3456.91   74.61   77.27   72.12    0.75
# 131    5800        807.09   3459.47   76.86   70.45   84.55    0.77
# 136    6000        647.47   3469.77   76.13   65.69   90.51    0.76
# 140    6200        661.89   3438.34   75.18   76.03   74.34    0.75
# 145    6400        706.63   3502.74   72.84   79.55   67.17    0.73
# 150    6600        678.03   3545.54   76.30   65.84   90.71    0.76
# 154    6800        853.50   3493.55   76.46   72.64   80.71    0.76
# 159    7000        786.85   3352.75   75.22   62.50   94.44    0.75
# ✔ Saved pipeline to output directory
# model-last

# %%
# Make predictios from above

# %%
train_ner = spacy.load("/content/model-best")
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)

# %%
text ="""Shivaji was the founder of the Maratha Empire. He was born in the Shivneri Fort in Maharashtra probably on 19 February 1630. He is named after a local goddess, Shivai Devi.

Shivaji is one of the revered historical figures of Maharashtra. He created an independent and sovereign state in the Maharashtra region. His mother, Raajmaata Jijabai was the daughter of Shri.Lakhuji Jadhavrao of Sindkhed. His father Shri.Shahajiraje Bhosale was a Maratha general in the Deccan.

Most of the territory in Maharashtra was then under the possession of the Nizamshah of Ahmednagar and the Adilshah of Bijapur who were known as the Deccan sultanates. The Mughals launched a campaign to conquer the Nizamshahi Kingdom. The Adilshah of Bijapur allied with the Mughals in this campaign. Shri. Shahajiraje Bhosale tried to rebel, but he could not withstand the combined might of the Mughals and the Adilshahi. The Nizamshahi kingdom came to an end in 1636. Thereafter Shri.Shahajiraje became a Sardar of the Adilshah of Bijapur and was posted in Karnataka. The region comprising Pune, Supe, Indapur, and Chakan Parganas located between the Bhima and Nira rivers which were vested in Shri. Shahdara as a jagir was continued by the Adilshah. Shri. Shahdara was also given a jagir of Bangalore. Rajmata Jijabai and Chh. Shivaji , stayed for a few years with Shahaji Raje at Bangalore until Shivaji I was twelve years old. Shri. Shahaji entrusted the administration of the Lakshmi jagir to Shivaji and Mata Jijabai.
Shivaji grew up amidst the hills and valleys of the Pune region under the guidance of his mother Raajmata Jijabai. His mother taught him the stories of the Hindu epics and scriptures such as Mahabharata and also stories of old mighty Hindu kingdoms such as the Vijayanagara. He was also trained in guerrilla warfare. He defeated the Mughal forces of Rai Bagan.
Foundation of the Maratha kingdom

Several small spurs run eastward from the sahyadri in the Pune region. The extremely rugged valleys enclosed by these are usually known as the Mavals or Khores each named after the stream running through it, or after the principal village. Collectively they are known as the Mavals. The inhabitants of this region who are called the Mavalas were extremely hardy people. Shivaji started the work of founding the Swaraj - self-rule - in this region. He used the geographical features of the Maval region. He created a feeling of trust and affection in minds of the people. Many associates, companions, and Mavalas joined him in his work of founding Swaraj. The objective of Shivaji in founding the Swaraj is clearly expressed in his official seal or Mudra which is in Sanskrit. Through this Mudra, Shivaji Maharaj assured his people that ‘ever-increasing like the crescent moon, the kingdom of Shivaji, son of Shahaji, will always seek the welfare of the people.
The Capture of Javali.

The region of Javali in the Satara district was important. Many routes to the Konkan were through Javali. For the expansion of the Swaraj in the Konkan, it was essential to control that region. The region of Javali was ruled by Chandrarao More, a powerful Sardar in the Adilshahi. Shivaji attacked Javali and captured it in A.D. 1656. Then he also captured Rairi. This strong fort, later under the name of Raigad, was to become his capital. He built the Pratapgad fort in the Javali valley to protect the newly conquered territory and to control the Paar pass. The victory at Javali led to the expansion of the Swaraj in Konkan. Shivaji then crossed the Ghats and descended into Konkan. He captured Kalyan and Bhivandi on the Konkan coast which were under the control of Adilshahi. Shivaji also captured forts like Mahuli, Lohagad, Tunga, Tikona, Visapur, Songad, Karnala, Tala and Ghosala, in the Konkan. Shivaji was able to command the coast line because of his acquisition of this territory in the Konkan. He came in contact with the Portuguese, the British and the Siddi powers on the western coast. The Siddi controlled the fort of Janjira and the areas around, including Danda-Rajpuri. Wherever in future these powers created obstacles in the work of expanding the Swaraj, Shivaji tried to curb their activities.
The Establishment of Maratha Navy"""

# %%
doc = train_ner(text)

# %%
for ents in doc.ents:
  print(ents.text ,"==>" ,ents.label_)
# Out:
# Shivaji ==> MAHARAJ
# Shivaji ==> MAHARAJ
# Raajmaata Jijabai ==> RAJMATA
# Shri.Shahajiraje Bhosale ==> MAHARAJ
# Nizamshah ==> DUSHMAN
# Adilshah ==> DUSHMAN
# Mughals ==> DUSHMAN
# Nizamshahi ==> DUSHMAN
# Adilshah ==> DUSHMAN
# Mughals ==> DUSHMAN
# Shri. Shahajiraje ==> MAHARAJ
# Mughals ==> DUSHMAN
# Adilshahi. ==> DUSHMAN
# Nizamshahi kingdom ==> DUSHMAN
# 1636. ==> VARSH
# Shri.Shahajiraje ==> MAHARAJ
# Adilshah ==> DUSHMAN
# Adilshah. ==> DUSHMAN
# Rajmata Jijabai ==> RAJMATA
# Chh. Shivaji ==> MAHARAJ
# Shahaji Raje ==> MAHARAJ
# Shivaji ==> MAHARAJ
# Shri. Shahaji ==> MAHARAJ
# Shivaji ==> MAHARAJ
# Mata Jijabai. ==> RAJMATA
# Raajmata Jijabai. ==> RAJMATA
# Mughal ==> DUSHMAN

# %%
from transformers import pipeline

# %%
ner_model = pipeline(model = "dslim/bert-base-NER-uncased")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.26k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-base-NER-uncased were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
ner_model(text)
# Out:
# [{'entity': 'B-PER',
#   'score': 0.9824008,
#   'index': 1,
#   'word': 'shiva',
#   'start': 0,
#   'end': 5},
#  {'entity': 'I-PER',
#   'score': 0.78100306,
#   'index': 2,
#   'word': '##ji',
#   'start': 5,
#   'end': 7},
#  {'entity': 'B-MISC',
#   'score': 0.8752444,
#   'index': 8,
#   'word': 'mara',
#   'start': 31,
#   'end': 35},
#  {'entity': 'I-MISC',
#   'score': 0.9069552,
#   'index': 9,
#   'word': '##tha',
#   'start': 35,
#   'end': 38},
#  {'entity': 'B-LOC',
#   'score': 0.98736435,
#   'index': 17,
#   'word': 'shi',
#   'start': 66,
#   'end': 69},
#  {'entity': 'I-LOC',
#   'score': 0.9269225,
#   'index': 18,
#   'word': '##vn',
#   'start': 69,
#   'end': 71},
#  {'entity': 'I-LOC',
#   'score': 0.98827666,
#   'index': 19,
#   'word': '##eri',
#   'start': 71,
#   'end': 74},
#  {'entity': 'B-LOC',
#   'score': 0.99621946,
#   'index': 22,
#   'word': 'maharashtra',
#   'start': 83,
#   'end': 94},
#  {'entity': 'B-PER',
#   'score': 0.903849,
#   'index': 37,
#   'word': 'shiva',
#   'start': 160,
#   'end': 165},
#  {'entity': 'I-PER',
#   'score': 0.45400006,
#   'index': 38,
#   'word': '##i',
#   'start': 165,
#   'end': 166},
#  {'entity': 'I-PER',
#   'score': 0.79712963,
#   'index': 39,
#   'word': 'devi',
#   'start': 167,
#   'end': 171},
#  {'entity': 'B-PER',
#   'score': 0.9887939,
#   'index': 41,
#   'word': 'shiva',
#   'start': 174,
#   'end': 179},
#  {'entity': 'I-PER',
#   'score': 0.913295,
#   'index': 42,
#   'word': '##ji',
#   'start': 179,
#   'end': 181},
#  {'entity': 'B-LOC',
#   'score': 0.99549246,
#   'index': 51,
#   'word': 'maharashtra',
#   'start': 226,
#   'end': 237},
#  {'entity': 'B-LOC',
#   'score': 0.993665,
#   'index': 62,
#   'word': 'maharashtra',
#   'start': 292,
#   'end': 303},
#  {'entity': 'B-PER',
#   'score': 0.9871918,
#   'index': 68,
#   'word': 'ra',
#   'start': 324,
#   'end': 326},
#  {'entity': 'B-PER',
#   'score': 0.9811725,
#   'index': 69,
#   'word': '##aj',
#   'start': 326,
#   'end': 328},
#  {'entity': 'I-PER',
#   'score': 0.7765792,
#   'index': 70,
#   'word': '##ma',
#   'start': 328,
#   'end': 330},
#  {'entity': 'I-PER',
#   'score': 0.7732782,
#   'index': 71,
#   'word': '##ata',
#   'start': 330,
#   'end': 333},
#  {'entity': 'I-PER',
#   'score': 0.98879343,
#   'index': 72,
#   'word': 'ji',
#   'start': 334,
#   'end': 336},
#  {'entity': 'I-PER',
#   'score': 0.9917448,
#   'index': 73,
#   'word': '##ja',
#   'start': 336,
#   'end': 338},
#  {'entity': 'I-PER',
#   'score': 0.99124897,
#   'index': 74,
#   'word': '##bai',
#   'start': 338,
#   'end': 341},
#  {'entity': 'B-PER',
#   'score': 0.99040294,
#   'index': 81,
#   'word': 'la',
#   'start': 367,
#   'end': 369},
#  {'entity': 'I-PER',
#   'score': 0.7066005,
#   'index': 82,
#   'word': '##kh',
#   'start': 369,
#   'end': 371},
#  {'entity': 'I-PER',
#   'score': 0.8091322,
#   'index': 83,
#   'word': '##uj',
#   'start': 371,
#   'end': 373},
#  {'entity': 'I-PER',
#   'score': 0.97132677,
#   'index': 84,
#   'word': '##i',
#   'start': 373,
#   'end': 374},
#  {'entity': 'I-PER',
#   'score': 0.99521685,
#   'index': 85,
#   'word': 'ja',
#   'start': 375,
#   'end': 377},
#  {'entity': 'I-PER',
#   'score': 0.99356526,
#   'index': 86,
#   'word': '##dha',
#   'start': 377,
#   'end': 380},
#  {'entity': 'I-PER',
#   'score': 0.99045384,
#   'index': 87,
#   'word': '##vr',
#   'start': 380,
#   'end': 382},
#  {'entity': 'I-PER',
#   'score': 0.984385,
#   'index': 88,
#   'word': '##ao',
#   'start': 382,
#   'end': 384},
#  {'entity': 'B-LOC',
#   'score': 0.99481225,
#   'index': 90,
#   'word': 'sin',
#   'start': 388,
#   'end': 391},
#  {'entity': 'I-LOC',
#   'score': 0.9860188,
#   'index': 91,
#   'word': '##d',
#   'start': 391,
#   'end': 392},
#  {'entity': 'I-LOC',
#   'score': 0.9510052,
#   'index': 92,
#   'word': '##kh',
#   'start': 392,
#   'end': 394},
#  {'entity': 'I-LOC',
#   'score': 0.9910155,
#   'index': 93,
#   'word': '##ed',
#   'start': 394,
#   'end': 396},
#  {'entity': 'B-PER',
#   'score': 0.994284,
#   'index': 99,
#   'word': 'shah',
#   'start': 414,
#   'end': 418},
#  {'entity': 'I-PER',
#   'score': 0.7268716,
#   'index': 100,
#   'word': '##aj',
#   'start': 418,
#   'end': 420},
#  {'entity': 'I-PER',
#   'score': 0.91392356,
#   'index': 101,
#   'word': '##ira',
#   'start': 420,
#   'end': 423},
#  {'entity': 'I-PER',
#   'score': 0.9454859,
#   'index': 102,
#   'word': '##je',
#   'start': 423,
#   'end': 425},
#  {'entity': 'I-PER',
#   'score': 0.99602413,
#   'index': 103,
#   'word': 'b',
#   'start': 426,
#   'end': 427},
#  {'entity': 'I-PER',
#   'score': 0.99021566,
#   'index': 104,
#   'word': '##hos',
#   'start': 427,
#   'end': 430},
#  {'entity': 'I-PER',
#   'score': 0.9883365,
#   'index': 105,
#   'word': '##ale',
#   'start': 430,
#   'end': 433},
#  {'entity': 'B-MISC',
#   'score': 0.9938909,
#   'index': 108,
#   'word': 'mara',
#   'start': 440,
#   'end': 444},
#  {'entity': 'I-MISC',
#   'score': 0.9778487,
#   'index': 109,
#   'word': '##tha',
#   'start': 444,
#   'end': 447},
#  {'entity': 'B-LOC',
#   'score': 0.9911991,
#   'index': 113,
#   'word': 'decca',
#   'start': 463,
#   'end': 468},
#  {'entity': 'I-LOC',
#   'score': 0.988473,
#   'index': 114,
#   'word': '##n',
#   'start': 468,
#   'end': 469},
#  {'entity': 'B-LOC',
#   'score': 0.99522626,
#   'index': 121,
#   'word': 'maharashtra',
#   'start': 497,
#   'end': 508},
#  {'entity': 'B-MISC',
#   'score': 0.6871854,
#   'index': 129,
#   'word': 'ni',
#   'start': 546,
#   'end': 548},
#  {'entity': 'I-MISC',
#   'score': 0.39736548,
#   'index': 130,
#   'word': '##zam',
#   'start': 548,
#   'end': 551},
#  {'entity': 'I-MISC',
#   'score': 0.56953514,
#   'index': 131,
#   'word': '##shah',
#   'start': 551,
#   'end': 555},
#  {'entity': 'B-LOC',
#   'score': 0.99569184,
#   'index': 133,
#   'word': 'ahmed',
#   'start': 559,
#   'end': 564},
#  {'entity': 'I-LOC',
#   'score': 0.98974,
#   'index': 134,
#   'word': '##nagar',
#   'start': 564,
#   'end': 569},
#  {'entity': 'B-MISC',
#   'score': 0.5588019,
#   'index': 137,
#   'word': 'adi',
#   'start': 578,
#   'end': 581},
#  {'entity': 'I-MISC',
#   'score': 0.8002165,
#   'index': 138,
#   'word': '##ls',
#   'start': 581,
#   'end': 583},
#  {'entity': 'I-MISC',
#   'score': 0.66515696,
#   'index': 139,
#   'word': '##ha',
#   'start': 583,
#   'end': 585},
#  {'entity': 'I-MISC',
#   'score': 0.44275767,
#   'index': 140,
#   'word': '##h',
#   'start': 585,
#   'end': 586},
#  {'entity': 'B-LOC',
#   'score': 0.99324,
#   'index': 142,
#   'word': 'bi',
#   'start': 590,
#   'end': 592},
#  {'entity': 'I-LOC',
#   'score': 0.9690456,
#   'index': 143,
#   'word': '##ja',
#   'start': 592,
#   'end': 594},
#  {'entity': 'I-LOC',
#   'score': 0.99013865,
#   'index': 144,
#   'word': '##pur',
#   'start': 594,
#   'end': 597},
#  {'entity': 'B-LOC',
#   'score': 0.9662203,
#   'index': 150,
#   'word': 'decca',
#   'start': 620,
#   'end': 625},
#  {'entity': 'I-LOC',
#   'score': 0.77021706,
#   'index': 151,
#   'word': '##n',
#   'start': 625,
#   'end': 626},
#  {'entity': 'B-MISC',
#   'score': 0.98655695,
#   'index': 156,
#   'word': 'mughal',
#   'start': 643,
#   'end': 649},
#  {'entity': 'B-LOC',
#   'score': 0.6987219,
#   'index': 164,
#   'word': 'ni',
#   'start': 686,
#   'end': 688},
#  {'entity': 'I-LOC',
#   'score': 0.7077496,
#   'index': 165,
#   'word': '##zam',
#   'start': 688,
#   'end': 691},
#  {'entity': 'I-LOC',
#   'score': 0.5416792,
#   'index': 166,
#   'word': '##shah',
#   'start': 691,
#   'end': 695},
#  {'entity': 'I-MISC',
#   'score': 0.5201726,
#   'index': 167,
#   'word': '##i',
#   'start': 695,
#   'end': 696},
#  {'entity': 'B-ORG',
#   'score': 0.480003,
#   'index': 171,
#   'word': 'adi',
#   'start': 710,
#   'end': 713},
#  {'entity': 'I-MISC',
#   'score': 0.48504648,
#   'index': 172,
#   'word': '##ls',
#   'start': 713,
#   'end': 715},
#  {'entity': 'I-LOC',
#   'score': 0.61366266,
#   'index': 173,
#   'word': '##ha',
#   'start': 715,
#   'end': 717},
#  {'entity': 'I-LOC',
#   'score': 0.40810803,
#   'index': 174,
#   'word': '##h',
#   'start': 717,
#   'end': 718},
#  {'entity': 'B-LOC',
#   'score': 0.99622846,
#   'index': 176,
#   'word': 'bi',
#   'start': 722,
#   'end': 724},
#  {'entity': 'I-LOC',
#   'score': 0.98009264,
#   'index': 177,
#   'word': '##ja',
#   'start': 724,
#   'end': 726},
#  {'entity': 'I-LOC',
#   'score': 0.99073094,
#   'index': 178,
#   'word': '##pur',
#   'start': 726,
#   'end': 729},
#  {'entity': 'B-MISC',
#   'score': 0.98858684,
#   'index': 182,
#   'word': 'mughal',
#   'start': 746,
#   'end': 752},
#  {'entity': 'B-PER',
#   'score': 0.99589396,
#   'index': 190,
#   'word': 'shah',
#   'start': 778,
#   'end': 782},
#  {'entity': 'I-PER',
#   'score': 0.6966808,
#   'index': 191,
#   'word': '##aj',
#   'start': 782,
#   'end': 784},
#  {'entity': 'I-PER',
#   'score': 0.9321621,
#   'index': 192,
#   'word': '##ira',
#   'start': 784,
#   'end': 787},
#  {'entity': 'I-PER',
#   'score': 0.93645215,
#   'index': 193,
#   'word': '##je',
#   'start': 787,
#   'end': 789},
#  {'entity': 'I-PER',
#   'score': 0.99589324,
#   'index': 194,
#   'word': 'b',
#   'start': 790,
#   'end': 791},
#  {'entity': 'I-PER',
#   'score': 0.99181455,
#   'index': 195,
#   'word': '##hos',
#   'start': 791,
#   'end': 794},
#  {'entity': 'I-PER',
#   'score': 0.98695964,
#   'index': 196,
#   'word': '##ale',
#   'start': 794,
#   'end': 797},
#  {'entity': 'B-MISC',
#   'score': 0.98730415,
#   'index': 211,
#   'word': 'mughal',
#   'start': 867,
#   'end': 873},
#  {'entity': 'B-LOC',
#   'score': 0.54274154,
#   'index': 215,
#   'word': 'adi',
#   'start': 883,
#   'end': 886},
#  {'entity': 'I-LOC',
#   'score': 0.5236456,
#   'index': 216,
#   'word': '##ls',
#   'start': 886,
#   'end': 888},
#  {'entity': 'I-LOC',
#   'score': 0.78324443,
#   'index': 217,
#   'word': '##ha',
#   'start': 888,
#   'end': 890},
#  {'entity': 'I-MISC',
#   'score': 0.4223723,
#   'index': 218,
#   'word': '##hi',
#   'start': 890,
#   'end': 892},
#  {'entity': 'B-LOC',
#   'score': 0.92976826,
#   'index': 221,
#   'word': 'ni',
#   'start': 898,
#   'end': 900},
#  {'entity': 'I-LOC',
#   'score': 0.9322271,
#   'index': 222,
#   'word': '##zam',
#   'start': 900,
#   'end': 903},
#  {'entity': 'I-LOC',
#   'score': 0.92922515,
#   'index': 223,
#   'word': '##shah',
#   'start': 903,
#   'end': 907},
#  {'entity': 'I-LOC',
#   'score': 0.888312,
#   'index': 224,
#   'word': '##i',
#   'start': 907,
#   'end': 908},
#  {'entity': 'B-PER',
#   'score': 0.48878884,
#   'index': 235,
#   'word': 'shri',
#   'start': 952,
#   'end': 956},
#  {'entity': 'B-PER',
#   'score': 0.9815298,
#   'index': 237,
#   'word': 'shah',
#   'start': 957,
#   'end': 961},
#  {'entity': 'I-PER',
#   'score': 0.9480052,
#   'index': 238,
#   'word': '##aj',
#   'start': 961,
#   'end': 963},
#  {'entity': 'I-PER',
#   'score': 0.97681105,
#   'index': 239,
#   'word': '##ira',
#   'start': 963,
#   'end': 966},
#  {'entity': 'I-PER',
#   'score': 0.9817888,
#   'index': 240,
#   'word': '##je',
#   'start': 966,
#   'end': 968},
#  {'entity': 'B-LOC',
#   'score': 0.5853886,
#   'index': 247,
#   'word': 'adi',
#   'start': 992,
#   'end': 995},
#  {'entity': 'I-LOC',
#   'score': 0.8371281,
#   'index': 248,
#   'word': '##ls',
#   'start': 995,
#   'end': 997},
#  {'entity': 'I-LOC',
#   'score': 0.8851908,
#   'index': 249,
#   'word': '##ha',
#   'start': 997,
#   'end': 999},
#  {'entity': 'I-LOC',
#   'score': 0.7464768,
#   'index': 250,
#   'word': '##h',
#   'start': 999,
#   'end': 1000},
#  {'entity': 'B-LOC',
#   'score': 0.995738,
#   'index': 252,
#   'word': 'bi',
#   'start': 1004,
#   'end': 1006},
#  {'entity': 'I-LOC',
#   'score': 0.9838689,
#   'index': 253,
#   'word': '##ja',
#   'start': 1006,
#   'end': 1008},
#  {'entity': 'I-LOC',
#   'score': 0.99152666,
#   'index': 254,
#   'word': '##pur',
#   'start': 1008,
#   'end': 1011},
#  {'entity': 'B-LOC',
#   'score': 0.99705267,
#   'index': 259,
#   'word': 'karnataka',
#   'start': 1030,
#   'end': 1039},
#  {'entity': 'B-LOC',
#   'score': 0.99566156,
#   'index': 264,
#   'word': 'pune',
#   'start': 1063,
#   'end': 1067},
#  {'entity': 'B-LOC',
#   'score': 0.987417,
#   'index': 266,
#   'word': 'su',
#   'start': 1069,
#   'end': 1071},
#  {'entity': 'I-LOC',
#   'score': 0.98858637,
#   'index': 267,
#   'word': '##pe',
#   'start': 1071,
#   'end': 1073},
#  {'entity': 'B-LOC',
#   'score': 0.99173963,
#   'index': 269,
#   'word': 'ind',
#   'start': 1075,
#   'end': 1078},
#  {'entity': 'I-LOC',
#   'score': 0.98539805,
#   'index': 270,
#   'word': '##ap',
#   'start': 1078,
#   'end': 1080},
#  {'entity': 'I-LOC',
#   'score': 0.9862592,
#   'index': 271,
#   'word': '##ur',
#   'start': 1080,
#   'end': 1082},
#  {'entity': 'B-LOC',
#   'score': 0.9888915,
#   'index': 274,
#   'word': 'cha',
#   'start': 1088,
#   'end': 1091},
#  {'entity': 'I-LOC',
#   'score': 0.9880881,
#   'index': 275,
#   'word': '##kan',
#   'start': 1091,
#   'end': 1094},
#  {'entity': 'I-LOC',
#   'score': 0.98820364,
#   'index': 276,
#   'word': 'par',
#   'start': 1095,
#   'end': 1098},
#  {'entity': 'I-LOC',
#   'score': 0.9888755,
#   'index': 277,
#   'word': '##gan',
#   'start': 1098,
#   'end': 1101},
#  {'entity': 'I-LOC',
#   'score': 0.95719224,
#   'index': 278,
#   'word': '##as',
#   'start': 1101,
#   'end': 1103},
#  {'entity': 'B-LOC',
#   'score': 0.9717733,
#   'index': 282,
#   'word': 'b',
#   'start': 1124,
#   'end': 1125},
#  {'entity': 'I-LOC',
#   'score': 0.9783635,
#   'index': 283,
#   'word': '##hima',
#   'start': 1125,
#   'end': 1129},
#  {'entity': 'B-LOC',
#   'score': 0.97115695,
#   'index': 285,
#   'word': 'ni',
#   'start': 1134,
#   'end': 1136},
#  {'entity': 'I-LOC',
#   'score': 0.98367506,
#   'index': 286,
#   'word': '##ra',
#   'start': 1136,
#   'end': 1138},
#  {'entity': 'B-PER',
#   'score': 0.60634506,
#   'index': 294,
#   'word': 'shah',
#   'start': 1173,
#   'end': 1177},
#  {'entity': 'I-LOC',
#   'score': 0.9391992,
#   'index': 295,
#   'word': '##dara',
#   'start': 1177,
#   'end': 1181},
#  {'entity': 'B-LOC',
#   'score': 0.8252278,
#   'index': 305,
#   'word': 'adi',
#   'start': 1214,
#   'end': 1217},
#  {'entity': 'I-LOC',
#   'score': 0.9452931,
#   'index': 306,
#   'word': '##ls',
#   'start': 1217,
#   'end': 1219},
#  {'entity': 'I-LOC',
#   'score': 0.9524421,
#   'index': 307,
#   'word': '##ha',
#   'start': 1219,
#   'end': 1221},
#  {'entity': 'I-LOC',
#   'score': 0.93810874,
#   'index': 308,
#   'word': '##h',
#   'start': 1221,
#   'end': 1222},
#  {'entity': 'B-PER',
#   'score': 0.5532283,
#   'index': 310,
#   'word': 'shri',
#   'start': 1224,
#   'end': 1228},
#  {'entity': 'B-PER',
#   'score': 0.89867663,
#   'index': 312,
#   'word': 'shah',
#   'start': 1230,
#   'end': 1234},
#  {'entity': 'I-PER',
#   'score': 0.98740524,
#   'index': 313,
#   'word': '##dara',
#   'start': 1234,
#   'end': 1238},
#  {'entity': 'B-LOC',
#   'score': 0.99686414,
#   'index': 322,
#   'word': 'bangalore',
#   'start': 1265,
#   'end': 1274},
#  {'entity': 'B-PER',
#   'score': 0.9897474,
#   'index': 324,
#   'word': 'raj',
#   'start': 1276,
#   'end': 1279},
#  {'entity': 'I-PER',
#   'score': 0.78090113,
#   'index': 325,
#   'word': '##mata',
#   'start': 1279,
#   'end': 1283},
#  {'entity': 'I-PER',
#   'score': 0.9830624,
#   'index': 326,
#   'word': 'ji',
#   'start': 1284,
#   'end': 1286},
#  {'entity': 'I-PER',
#   'score': 0.9825508,
#   'index': 327,
#   'word': '##ja',
#   'start': 1286,
#   'end': 1288},
#  {'entity': 'I-PER',
#   'score': 0.9416259,
#   'index': 328,
#   'word': '##bai',
#   'start': 1288,
#   'end': 1291},
#  {'entity': 'B-PER',
#   'score': 0.9823813,
#   'index': 330,
#   'word': 'ch',
#   'start': 1296,
#   'end': 1298},
#  {'entity': 'B-PER',
#   'score': 0.52801704,
#   'index': 331,
#   'word': '##h',
#   'start': 1298,
#   'end': 1299},
#  {'entity': 'B-PER',
#   'score': 0.9824238,
#   'index': 333,
#   'word': 'shiva',
#   'start': 1301,
#   'end': 1306},
#  {'entity': 'I-PER',
#   'score': 0.98862386,
#   'index': 334,
#   'word': '##ji',
#   'start': 1306,
#   'end': 1308},
#  {'entity': 'B-PER',
#   'score': 0.9956911,
#   'index': 342,
#   'word': 'shah',
#   'start': 1339,
#   'end': 1343},
#  {'entity': 'I-PER',
#   'score': 0.9336674,
#   'index': 343,
#   'word': '##aj',
#   'start': 1343,
#   'end': 1345},
#  {'entity': 'I-PER',
#   'score': 0.9507789,
#   'index': 344,
#   'word': '##i',
#   'start': 1345,
#   'end': 1346},
#  {'entity': 'I-PER',
#   'score': 0.99451727,
#   'index': 345,
#   'word': 'raj',
#   'start': 1347,
#   'end': 1350},
#  {'entity': 'I-PER',
#   'score': 0.982743,
#   'index': 346,
#   'word': '##e',
#   'start': 1350,
#   'end': 1351},
#  {'entity': 'B-LOC',
#   'score': 0.996923,
#   'index': 348,
#   'word': 'bangalore',
#   'start': 1355,
#   'end': 1364},
#  {'entity': 'B-PER',
#   'score': 0.9836578,
#   'index': 350,
#   'word': 'shiva',
#   'start': 1371,
#   'end': 1376},
#  {'entity': 'I-PER',
#   'score': 0.8828577,
#   'index': 351,
#   'word': '##ji',
#   'start': 1376,
#   'end': 1378},
#  {'entity': 'I-PER',
#   'score': 0.82152975,
#   'index': 352,
#   'word': 'i',
#   'start': 1379,
#   'end': 1380},
#  {'entity': 'B-PER',
#   'score': 0.9811602,
#   'index': 360,
#   'word': 'shah',
#   'start': 1409,
#   'end': 1413},
#  {'entity': 'I-PER',
#   'score': 0.9705546,
#   'index': 361,
#   'word': '##aj',
#   'start': 1413,
#   'end': 1415},
#  {'entity': 'I-PER',
#   'score': 0.9732554,
#   'index': 362,
#   'word': '##i',
#   'start': 1415,
#   'end': 1416},
#  {'entity': 'B-LOC',
#   'score': 0.5283774,
#   'index': 368,
#   'word': 'lakshmi',
#   'start': 1453,
#   'end': 1460},
#  {'entity': 'I-MISC',
#   'score': 0.5178164,
#   'index': 370,
#   'word': '##gi',
#   'start': 1463,
#   'end': 1465},
#  {'entity': 'B-PER',
#   'score': 0.9941941,
#   'index': 373,
#   'word': 'shiva',
#   'start': 1470,
#   'end': 1475},
#  {'entity': 'I-PER',
#   'score': 0.9633977,
#   'index': 374,
#   'word': '##ji',
#   'start': 1475,
#   'end': 1477},
#  {'entity': 'B-PER',
#   'score': 0.9301636,
#   'index': 376,
#   'word': 'mata',
#   'start': 1482,
#   'end': 1486},
#  {'entity': 'I-PER',
#   'score': 0.89993316,
#   'index': 377,
#   'word': 'ji',
#   'start': 1487,
#   'end': 1489},
#  {'entity': 'I-PER',
#   'score': 0.9816467,
#   'index': 378,
#   'word': '##ja',
#   'start': 1489,
#   'end': 1491},
#  {'entity': 'I-PER',
#   'score': 0.9854455,
#   'index': 379,
#   'word': '##bai',
#   'start': 1491,
#   'end': 1494},
#  {'entity': 'B-PER',
#   'score': 0.99271554,
#   'index': 381,
#   'word': 'shiva',
#   'start': 1497,
#   'end': 1502},
#  {'entity': 'I-PER',
#   'score': 0.9084675,
#   'index': 382,
#   'word': '##ji',
#   'start': 1502,
#   'end': 1504},
#  {'entity': 'B-LOC',
#   'score': 0.9941023,
#   'index': 392,
#   'word': 'pune',
#   'start': 1549,
#   'end': 1553},
#  {'entity': 'B-PER',
#   'score': 0.9932427,
#   'index': 400,
#   'word': 'ra',
#   'start': 1594,
#   'end': 1596},
#  {'entity': 'B-PER',
#   'score': 0.9844189,
#   'index': 401,
#   'word': '##aj',
#   'start': 1596,
#   'end': 1598},
#  {'entity': 'I-PER',
#   'score': 0.73932594,
#   'index': 402,
#   'word': '##mata',
#   'start': 1598,
#   'end': 1602},
#  {'entity': 'I-PER',
#   'score': 0.9880091,
#   'index': 403,
#   'word': 'ji',
#   'start': 1603,
#   'end': 1605},
#  {'entity': 'I-PER',
#   'score': 0.9870905,
#   'index': 404,
#   'word': '##ja',
#   'start': 1605,
#   'end': 1607},
#  {'entity': 'I-PER',
#   'score': 0.9784889,
#   'index': 405,
#   'word': '##bai',
#   'start': 1607,
#   'end': 1610},
#  {'entity': 'B-MISC',
#   'score': 0.99582654,
#   'index': 415,
#   'word': 'hindu',
#   'start': 1653,
#   'end': 1658},
#  {'entity': 'B-MISC',
#   'score': 0.986432,
#   'index': 422,
#   'word': 'maha',
#   'start': 1688,
#   'end': 1692},
#  {'entity': 'I-MISC',
#   'score': 0.9687899,
#   'index': 423,
#   'word': '##bha',
#   'start': 1692,
#   'end': 1695},
#  {'entity': 'I-MISC',
#   'score': 0.97137815,
#   'index': 424,
#   'word': '##rata',
#   'start': 1695,
#   'end': 1699},
#  {'entity': 'B-MISC',
#   'score': 0.9952277,
#   'index': 431,
#   'word': 'hindu',
#   'start': 1731,
#   'end': 1736},
#  {'entity': 'B-ORG',
#   'score': 0.4894484,
#   'index': 436,
#   'word': 'vijay',
#   'start': 1758,
#   'end': 1763},
#  {'entity': 'I-LOC',
#   'score': 0.7841996,
#   'index': 437,
#   'word': '##ana',
#   'start': 1763,
#   'end': 1766},
#  {'entity': 'I-LOC',
#   'score': 0.90044945,
#   'index': 438,
#   'word': '##gara',
#   'start': 1766,
#   'end': 1770},
#  {'entity': 'B-MISC',
#   'score': 0.99487525,
#   'index': 451,
#   'word': 'mughal',
#   'start': 1830,
#   'end': 1836},
#  {'entity': 'B-LOC',
#   'score': 0.8453428,
#   'index': 454,
#   'word': 'rai',
#   'start': 1847,
#   'end': 1850},
#  {'entity': 'I-LOC',
#   'score': 0.93611866,
#   'index': 455,
#   'word': 'bag',
#   'start': 1851,
#   'end': 1854},
#  {'entity': 'I-LOC',
#   'score': 0.9391059,
#   'index': 456,
#   'word': '##an',
#   'start': 1854,
#   'end': 1856},
#  {'entity': 'B-MISC',
#   'score': 0.87946105,
#   'index': 461,
#   'word': 'mara',
#   'start': 1876,
#   'end': 1880},
#  {'entity': 'I-MISC',
#   'score': 0.82998216,
#   'index': 462,
#   'word': '##tha',
#   'start': 1880,
#   'end': 1883},
#  {'entity': 'B-LOC',
#   'score': 0.86980444,
#   'index': 471,
#   'word': 'sa',
#   'start': 1935,
#   'end': 1937},
#  {'entity': 'I-LOC',
#   'score': 0.9492072,
#   'index': 472,
#   'word': '##hya',
#   'start': 1937,
#   'end': 1940},
#  {'entity': 'I-LOC',
#   'score': 0.9505927,
#   'index': 473,
#   'word': '##dr',
#   'start': 1940,
#   'end': 1942},
#  {'entity': 'I-LOC',
#   'score': 0.9102445,
#   'index': 474,
#   'word': '##i',
#   'start': 1942,
#   'end': 1943},
#  {'entity': 'B-LOC',
#   'score': 0.99571264,
#   'index': 477,
#   'word': 'pune',
#   'start': 1951,
#   'end': 1955},
#  {'entity': 'B-LOC',
#   'score': 0.7352423,
#   'index': 492,
#   'word': 'ma',
#   'start': 2036,
#   'end': 2038},
#  {'entity': 'I-LOC',
#   'score': 0.49163783,
#   'index': 493,
#   'word': '##val',
#   'start': 2038,
#   'end': 2041},
#  {'entity': 'B-LOC',
#   'score': 0.8559901,
#   'index': 496,
#   'word': 'k',
#   'start': 2046,
#   'end': 2047},
#  {'entity': 'I-LOC',
#   'score': 0.46744227,
#   'index': 497,
#   'word': '##hore',
#   'start': 2047,
#   'end': 2051}]
